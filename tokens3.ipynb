# %% [markdown]
# <a href="https://colab.research.google.com/github/Otter2022/Oil_Marketing_Campaign/blob/main/tokens3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!/usr/bin/env python3
#tokens3
import csv
import re
import sys
import os

from google.colab import drive
drive.mount("/content/drive", force_remount=True)

source_data = '/content/drive/MyDrive/ColabNotebooks/FinalProject_AI/Source_Data/'
source_data_output = '/content/drive/MyDrive/ColabNotebooks/FinalProject_AI/Source_Data_Output/'
source_code = '/content/drive/MyDrive/ColabNotebooks/FinalProject_AI/Source_Code/'
admin = '/content/drive/MyDrive/ColabNotebooks/FinalProject_AI/Admin/'
backups = '/content/drive/MyDrive/ColabNotebooks/FinalProject_AI/Backups/'

#The lists contained in the marketing_compaign_oil.py file serves as a header for name pre-processing
#contains exclude, compiled_patterns for exclude, fix_abbreviations, honorifics, suffixes, suffixes_roman, etc.
marketing_campaign_oil = source_code+'marketing_campaign_oil.py'
with open(marketing_campaign_oil, 'r') as f:
    exec(f.read())
    f.close()

input_file = source_data + 'tokens3_21379_CSV.csv'
#input_file = basepath + 'tokens2_test_csv.csv'
output_file = source_data_output + 'tokens3_formatted_output.csv'

# Test for successul package import marketing_campaign_oil
print(honorifics)
print(suffixes)
print(suffixes_roman)
# Out:
# Mounted at /content/drive
# ['Dr', 'Doctor', 'Mr', 'Mrs', 'Ms', 'Miss', 'Prof', 'Professor', 'Sir', 'Madam', 'Dame', 'Lord', 'Lady', 'Rev', 'Reverend', 'Hon', 'Honorable', 'Capt', 'Captain', 'Major', 'Col', 'Colonel', 'Gen', 'General', 'Adm', 'Admiral', 'Sgt', 'Sergeant', 'Lt', 'Lieutenant', 'Chief', 'Officer', 'Judge', 'Magistrate', 'Sen', 'Senator', 'Rep', 'Representative', 'Amb', 'Ambassador', 'Pres', 'President', 'VP', 'Vice President', 'Gov', 'Governor', 'Mayor']
# ['Jr', 'Sr', 'Esq', 'Esquire', 'PhD', 'MD', 'DDS', 'DVM', 'JD', 'CPA', 'RN', 'LPN', 'PE', 'Ret']
# ['V', 'IV', 'III', 'II', 'I']

# %%
def is_excluded(input_string):
    # Check if any compiled pattern matches the input string
    #I want to print the input_strings that are excluded
    for pattern in compiled_patterns:
        if pattern.match(input_string):
            print(f"Excluded: {input_string}")
            return True
    return False

def abbreviate(token):
  if token in fix_abbreviations.keys():
    return fix_abbreviations[token]
  else:
    return token


def rearrange_tokens(name):
    # Split the name into tokens
    tokens = name.split()

    # Process each token to fix abbreviations
    tokens = [abbreviate(token.strip()) for token in tokens]

    # Capitalize each token appropriately
    tokens = [token.capitalize() if token not in suffixes_roman else token for token in tokens]

    if len(tokens) == 3:
        token1, token2, token3 = tokens[0], tokens[1], tokens[2]

        # Exclude if any token for the owner name is in the exclude list
        for token in tokens:
            if is_excluded(token):
                print(f"Excluded: {name}")
                return "Miss"

        if token1 in honorifics:
            return f"{token1} {token3} {token2}"
        elif token3 in suffixes or token3 in suffixes_roman:
            return f"{token1} {token2} {token3}"
        elif token2 == "Trust":
            return f"{token1} {token3} {token2}"
        elif token3 == "Trust":#do nothing
            return f"{token1} {token2} {token3}"
        elif token2 == "Family":
            return f"{token1} {token3} {token2}"
        elif token3 == "Family":
            return f"{token1} {token3} {token2}"
        elif token1.isalpha() and token2.isalpha() and token3.isalpha():
            return f"{token2} {token3} {token1}"
    return "Miss"


def process_names(input_file, output_file):
    with open(input_file, 'r') as csvfile:
        reader = csv.reader(csvfile)
        # OwnerNames in 1st col
        names = [row[0] for row in reader]

    # Process the names
    names = [name.strip() for name in names]

    formatted_names = [(name, rearrange_tokens(name)) for name in names]
    misses = 0
    total = len(formatted_names)

    # Try different methods if the above one fails
    try:
        with open(output_file, 'w', newline='') as csvfile:
            writer = csv.writer(csvfile)
            writer.writerow(['column1', 'column2'])  # Write headers
            for original, rearranged in formatted_names:
                if rearranged == 'Miss':
                    misses += 1
                else:
                    writer.writerow([original, rearranged])
    except TypeError:
        with open(output_file, 'w') as csvfile:
            writer = csv.writer(csvfile)
            writer.writerow(['column1', 'column2'])  # Write headers
            for original, rearranged in formatted_names:
                if rearranged == 'Miss':
                    misses += 1
                else:
                    writer.writerow([original, rearranged])

    return misses, total

# %%
def main():
    misses,total = process_names(input_file, output_file)
    print(f"Total: {total}")
    print(f"Errors: {misses}")
    print(f"Miss percentage {(float(misses)/float(total))*100.00}%.")

if __name__ == "__main__":
    main()
# Out:
# Excluded: Deceased
# Excluded: CLEMENT GAYE DECEASED
# Excluded: Management
# Excluded: COASTAL MANAGEMENT TRUST
# Excluded: Survivors
# Excluded: JONES SURVIVORS TRUSTS
# Excluded: Management
# Excluded: KEYES MANAGEMENT TRUST
# Excluded: Management
# Excluded: MCRAE MANAGEMENT TRUST
# Excluded: Management
# Excluded: MENDELL MANAGEMENT TR
# Excluded: Oklahoma
# Excluded: MERCO OF OKLAHOMA
# Excluded: Oklahoma
# Excluded: OKLAHOMA MEDICAL RESEARCH
# Excluded: Holdings
# Excluded: BIG STAR HOLDINGS
# Excluded: Deceased
# Excluded: BULLARD LENA DECEASED
# Excluded: Corpening
# Excluded: CORPENING MELISSA A
# Excluded: Deceased
# Excluded: EDWARDS LESTON DECEASED
# Excluded: Management
# Excluded: KMF MANAGEMENT TRUST
# Excluded: Deceased
# Excluded: MCGEE NADINE DECEASED
# Excluded: Deceased
# Excluded: NIX EULALA DECEASED
# Excluded: Deceased
# Excluded: REED OLGA DECEASED
# Excluded: Holdings
# Excluded: UNIVERSAL STRATEGIC HOLDINGS
# Excluded: Deceased
# Excluded: WYATT CAROL DECEASED
# Excluded: Deceased
# Excluded: YOUNG MERLE DECEASED
# Excluded: Survivors
# Excluded: MCREYNOLDS SURVIVORS TRUST
# Excluded: Holdings
# Excluded: DD SOUTHERN HOLDINGS
# Excluded: Survivor
# Excluded: GILL SURVIVOR TRUST
# Excluded: Funderburg
# Excluded: FUNDERBURG STANLEY B
# Excluded: Holdings
# Excluded: BLACK GOLD HOLDINGS
# Excluded: Fndn/tr
# Excluded: BURNETT-TIMKEN MEM FNDN/TR
# Excluded: Land&cattle
# Excluded: CORRIGAN SOUTHERN LAND&CATTLE
# Excluded: Oklahoma
# Excluded: DALTON OKLAHOMA FAMILY
# Excluded: Deceased
# Excluded: GREIF ALVIN DECEASED
# Excluded: Deceased
# Excluded: KOHUTEK VIRGINIA DECEASED
# Excluded: Corp/retirement
# Excluded: SABINE CORP/RETIREMENT TR
# Excluded: Corporati
# Excluded: SCHLACHTER OPERATING CORPORATI
# Excluded: Corp/palinbeck
# Excluded: SUGARBERRY O&G CORP/PALINBECK
# Excluded: Corp/bob
# Excluded: TIDEMARK CORP/BOB PEDDY
# Excluded: Survivors
# Excluded: ABBEY SURVIVORS TRUST
# Excluded: Deceased
# Excluded: ALDRED MAXINE DECEASED
# Excluded: Survivors
# Excluded: HENDERSON SURVIVORS TRUST
# Excluded: Management
# Excluded: HERITAGE RESOURCE MANAGEMENT
# Excluded: Management
# Excluded: SKW MANAGEMENT TRUST
# Excluded: Unknown-lse
# Excluded: UNKNOWN-LSE 361138 RI
# Excluded: Deceased
# Excluded: WARD LAFAYETTE DECEASED
# Excluded: Management
# Excluded: CHILES MANAGEMENT TRUST
# Excluded: Deceased
# Excluded: COLDIRON SHERILYN  DECEASED
# Excluded: Resources-oper
# Excluded: ENEX RESOURCES-OPER RIGHTS
# Excluded: Landsberg
# Excluded: LANDSBERG PATRICIA A
# Excluded: Oklahoma
# Excluded: MAP2004-OK AN OKLAHOMA
# Excluded: Holdings
# Excluded: MJ PHILLIPS HOLDINGS
# Excluded: Management
# Excluded: PEGASUS BUILDING MANAGEMENT
# Excluded: Survivors
# Excluded: RICHMOND SURVIVORS TRUST
# Excluded: Holdings
# Excluded: S COLE HOLDINGS
# Excluded: Texas/***exempt***
# Excluded: STATE OF TEXAS/***EXEMPT***
# Total: 23179
# Errors: 298
# Miss percentage 1.2856464903576514%.
